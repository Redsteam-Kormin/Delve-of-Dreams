# %% [markdown]
# <a href="https://colab.research.google.com/github/Redsteam-Kormin/Delve-of-Dreams/blob/silly-versions/Delve_of_Dreams_%3CS.UPDATE%3E.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Imports

import random

#Main Code

#Setup Game
exp = 0
level = 1
atk = 1
_def = 0
spd = 1
hp = 10
maxhp = 10
maxspd = 1
maxatk = 1
maxdef = 0
wpnatk = 0
izakused = 0
eqdef = 0
inv1 = "___"
inv2 = "___"
inv3 = "___"
inv4 = "___"
inv5 = "___"
print("-----------------------------")
print("Welcome To ")
print("                                                                                      .-'''-.                                                                                              ")
print("_______                          .---.                                               '   _    \                   _______                                                                  ")
print("\  ___ `'.         __.....__     |   |.----.     .----.   __.....__                /   /` '.   \                  \  ___ `'.                 __.....__               __  __   ___          ")
print(" ' |--.\  \    .-''         '.   |   | \    \   /    /.-''         '.             .   |     \  '   _.._            ' |--.\  \            .-''         '.            |  |/  `.'   `.        ")
print(" | |    \  '  /     .-''''-.  `. |   |  '   '. /'   //     .-''''-.  `.           |   '      |  '.' .._|           | |    \  ' .-,.--.  /     .-''''-.  `.          |   .-.  .-.   '       ")
print(" | |     |  '/     /________\   \|   |  |    |'    //     /________\   \          \    \     / / | '               | |     |  '|  .-. |/     /________\   \    __   |  |  |  |  |  |       ")
print(" | |     |  ||                  ||   |  |    ||    ||                  |           `.   ` ..' /__| |__             | |     |  || |  | ||                  | .:--.'. |  |  |  |  |  |     _ ")
print(" | |     ' .'\    .-------------'|   |  '.   `'   .'\    .-------------'              '-...-'`|__   __|            | |     ' .'| |  | |\    .-------------'/ |   \ ||  |  |  |  |  |   .' |")
print(" | |___.' /'  \    '-.____...---.|   |   \        /  \    '-.____...---.                         | |               | |___.' /' | |  '-  \    '-.____...---.`' __ | ||  |  |  |  |  |  .   | /")
print("/_______.'/    `.             .' |   |    \      /    `.             .'                          | |              /_______.'/  | |       `.             .'  .'.''| ||__|  |__|  |__|.'.'| |//")
print("\_______|/       `''-...... -'   '---'     '----'       `''-...... -'                            | |              \_______|/   | |         `''-...... -'   / /   | |_             .'.'.-'  / ")
print("                                                                                                 | |                           |_|                         \ \._,\ '/             .'   \_.'  ")
print("                                                                                                 |_|                                                        `--'  `'                         ")
print("-----------------------------")
print("WARNING: THIS DOES NOT SAVE")
print("-----------------------------")
name = input("What is your name? ")
if name == "Jacob":
  print("GO F*** YOURSELF")
menu = 0
#Game Starts Here VVV
while 1:
  if exp >= 100:
    print("{+}--------------------------------------{+}")
    print("Level Up")
    exp = exp - 100
    level = level + 1
    hp = hp + 5
    maxhp = maxhp + 5
    print("ATK | DEF | SPD ")
    actionL = input("Choose a Stat To Improve: ")
    if actionL == "ATK" or actionL == "atk" or actionL == "Attack" or actionL == "attack":
      maxatk = maxatk + 1
      atk = maxatk
    elif actionL == "DEF" or actionL == "def" or actionL == "Defense" or actionL == "defense":
      maxdef = maxdef+1
      _def = maxdef
    elif actionL == "SPD" or actionL == "spd" or actionL == "Speed" or actionL == "speed":
      maxspd = maxspd + 1
      spd = maxspd
  elif menu == 0:

    print("-----Menu-----")

    print("Stats")
    print("Fight")
    print("Inventory")

    actionM = input("What would you like to do? ")

    if actionM == "Stats" or actionM == "stats":
      print("+------------Stats------------+")
      print("Name: ", name)
      print("ATK: ", atk, "+", wpnatk)
      print("DEF: ", _def, "+", eqdef)
      print("SPD: ", spd)
      print("MAXHP: ", maxhp)
      print("+---------------+")
      print("EXP: ", exp)
      nxtlvl = (100 - exp)
      print("EXP to Next LVL: ", nxtlvl)
      print("Level: ", level)
      if izakused == "yes":
        print("-------------------")
        print("izak has been used.")
        print("-------------------")
    elif actionM == "dev":
      menu = -13
      print("Commands Are: ")
      print("levelset | izak | item '")
      actionM = input("Input: ")
      if actionM == "levelset":
        level = int(input("Level: "))
        menu = 0
      elif actionM == "izak":
        atk = 5000000
        _def = 5000000
        spd = 5000000
        hp = 5000000
        maxhp = 5000000
        menu = 0
        izakused = "yes"
      elif actionM == "item":
        cheeseburger = input("Item Name? ")
        inv5 = cheeseburger
        menu = 0
    elif actionM == "Inventory" or actionM == "inventory":
      print(inv1)
      print(inv2)
      print(inv3)
      print(inv4)
      print(inv5)
      actionI = input("What do you Want to Do? (Equip {Item Name}) (Delete {Slot [inv1, etc..]} (Menu) ")
      if actionI == "Equip Slime Sword":
        if inv1 == "Slime Sword":
          inv1 = "___"
          wpnatk = 1
        elif inv2 == "Slime Sword":
          inv2 = "___"
          wpnatk = 1
        elif inv3 == "Slime Sword":
          inv3 = "___"
          wpnatk = 1
        elif inv4 == "Slime Sword":
          inv4 = "___"
          wpnatk = 1
        elif inv5 == "Slime Sword":
          inv5 = "___"
          wpnatk = 1
      elif actionI == "Equip Rotted Sheild":
        if inv1 == "Rotted Sheild":
          inv1 = "___"
          eqdef = 1
        elif inv2 == "Rotted Sheild":
          inv2 = "___"
          eqdef = 1
        elif inv3 == "Rotted Sheild":
          inv3 = "___"
          eqdef = 1
        elif inv4 == "Rotted Sheild":
          inv4 = "___"
          eqdef = 1
        elif inv5 == "Rotted Sheild":
          inv5 = "___"
          eqdef = 1
      elif actionI == "Equip Book of Die":
        if inv5 == "Book of Die":
          inv5 = "___"
          wpnatk = 5318008
      elif actionI == "Delete inv1":
        inv1 = "___"
      elif actionI == "Delete inv2":
        inv2 = "___"
      elif actionI == "Delete inv3":
        inv3 = "___"
      elif actionI == "Delete inv4":
        inv4 = "___"
      elif actionI == "Delete inv5":
        inv5 = "___"
      elif actionI == "Menu" or actionI == "menu":
        menu = 0
    elif actionM == "Fight" or actionM == "fight":
      menu = 1
      print("[---]Battle[---]")
      enemy = (level + 1) or (level - 1)
      if enemy <= 2:
        fightnum = 1
        enemyhp = 5
        while fightnum == 1:
          if hp <= 0:
            print("You Died!")
            menu = 0
            fightnum = 0
            hp = maxhp
            spd = maxspd
            atk = maxatk
            _def = maxdef
            exp = exp - 3
          elif enemyhp <= 0:
            fightnum = 0
            menu = 0
            print("You Win!")
            exp = exp + 5 or exp + 6
            hp = maxhp
            spd = maxspd
            atk = maxatk
            _def = maxdef
            itemrng = int(input("Pick a Number between 1 and 10"))
            if itemrng == 2:
              if inv1 == "___":
                inv1 = "Slime Sword"
                print("You got an Item!")
              elif inv2 == "___":
                inv2 = "Slime Sword"
                print("You got an Item!")
              elif inv3 == "___":
                inv3 = "Slime Sword"
                print("You got an Item!")
              elif inv4 == "___":
                inv4 = "Slime Sword"
                print("You got an Item!")
              elif inv5 == "___":
                inv5 = "Slime Sword"
                print("You got an Item!")
              else:
                print("You got an item, but your inventory was full...")
            if itemrng == 7:
              if inv1 == "___":
                inv1 = "Rotted Sheild"
                print("You got an Item!")
              elif inv2 == "___":
                inv2 = "Rotted Sheild"
                print("You got an Item!")
              elif inv3 == "___":
                inv3 = "Rotted Sheild"
                print("You got an Item!")
              elif inv4 == "___":
                inv4 = "Rotted Sheild"
                print("You got an Item!")
              elif inv5 == "___":
                inv5 = "Rotted Sheild"
                print("You got an Item!")
              else:
                print("You got an Item, but your Inventory was full...")
          else:
            print("Slime")
            enemyatk = 0
            enemyatk = 1 or 2
            enemydef = 0
            enemyspd = 0
            print("HP: ", enemyhp)
            print("+-You-+")
            print("HP: ", hp)
            if enemyspd >= spd:
              print("Slime attacks for ", (enemyatk - _def), "dmg")
              enemydmg = 0
              enemydmg = enemyatk - _def
              hp = hp - enemydmg
              spd = maxspd
              _def = maxdef
            else:
              print("|Actions|")
              print("Attack")
              print("Defend")
              print("Run")
              actionB = input("What do you do? ")
              if actionB == "Attack" or actionB == "attack":
                enemyhp = enemyhp - (atk + wpnatk)
                spd = maxspd - 1
              elif actionB == "Defend" or actionB == "defend":
                _def = maxdef + 1
                spd = maxspd - 1
              elif actionB == "Run" or actionB == "run":
                fightnum = 0
                menu = 0
                print("You Ran Away")
  if actionM == "fight god":
     if not wpnatk >= 5318008:
       print("}---------{+}--------{")
       print("You Shouldn't Do That.")
       print("}---------{+}--------{")
     elif not level >= 9112001:
       print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ -o- ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
       print("Really? You may have the attack power, but you would not survive a single swing.")
       print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ -o- ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
     elif izakused == "yes":
       print("--===--")
       print("Really?")
       print("--===--")
     else:
        print(":::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::")
        print("So, You Really did it? You got the book, and are now Level 9112001. However, the lazy dev of this has not yet implemented me, check back later. My Apologies...")
        print(":::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::")
  if actionM == "sex" or actionM == "boobs":
    who = input("Who? ")
    if actionM == "sex":
      print("You should tell ", who, "that you want to have sex!")
    elif actionM == "boobs":
      print(f"Tell {who} you like their boobs!")
# Out:
# -----------------------------
# Welcome To
#                                                                                       .-'''-.
# _______                          .---.                                               '   _    \                   _______
# \  ___ `'.         __.....__     |   |.----.     .----.   __.....__                /   /` '.   \                  \  ___ `'.                 __.....__               __  __   ___
#  ' |--.\  \    .-''         '.   |   | \    \   /    /.-''         '.             .   |     \  '   _.._            ' |--.\  \            .-''         '.            |  |/  `.'   `.
#  | |    \  '  /     .-''''-.  `. |   |  '   '. /'   //     .-''''-.  `.           |   '      |  '.' .._|           | |    \  ' .-,.--.  /     .-''''-.  `.          |   .-.  .-.   '
#  | |     |  '/     /________\   \|   |  |    |'    //     /________\   \          \    \     / / | '               | |     |  '|  .-. |/     /________\   \    __   |  |  |  |  |  |
# ...

# %% [markdown]
# Delve of Dreams
# ----------------------------
# A Simple, In-The-Works RPG using python.
# I run this in Google Colab (use what you want).
# Text Only, and yes, I am terrible at coding.
#
#
# Current Features:
#
# -One Enemy
#
# -2 Equipabble Items
#
# -Bad RNG System
#
# -Working Menu
